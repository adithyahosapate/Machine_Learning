# %%
import urllib
from urllib.request import urlopen
url = 'http://karresults.nic.in/resultCET2017.asp'
response = urlopen("http://karresults.nic.in/indexCET2017.asp")
page_source = response.read()
from bs4 import BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')
table=soup.find("input")
print(table["value"])
import requests
payload={"frm_tokens":table["value"],"reg":"AA007"}
r = requests.post(url, data=payload)
#print(r.content)
soup = BeautifulSoup(r.content, 'html.parser')
print(soup)
# Out:
# 0.8893701
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Common Entrance Test  Results -  2017</title>
# <link href="css/bootstrap.css" rel="stylesheet"/>
# <style type="text/css">
# 	.textright{
# 		text-align : right;
# 		font-weight:bold;
# 	}
# 	.textcenter{
# 		text-align : center;
# 	}
#  </style>
# </head>
# <body>
# <div class="row col-lg-12" style="background-color: rgb(228, 156, 46);color:#fff;">
# <div class="col-lg-6 col-md-offset-3">
# <div style="text-align:center">
# <h3>KARNATAKA EXAMINATIONS AUTHORITY</h3>
# <h4>COMMON  ENTRANCE TEST- 2017</h4>
# </div>
# </div>
# </div>
# <div class="col-lg-6 col-md-offset-3">
# <div style="margin-top:1em">
# <table class="table" id="details">
# <tbody>
# <tr>
# <td>Name</td>
# <td colspan="3"><span style="font-weight: bold">  ANDAPPAGARI KANTHIKIRAN REDDY</span></td>
# </tr>
# <tr>
# <td>CET NUMBER</td>
# <td><span style="font-weight: bold"> AA007</span></td>
# </tr>
# </tbody>
# </table>
# </div>
# <p><a class="btn btn-warning" href="indexCET2017.asp">Back</a></p>
# <div class="panel panel-primary col-lg-6 col-sm-12">
# <!-- Default panel contents -->
# <div class="panel-heading">Rank</div>
# <table class="table table-bordered table-striped">
# <tbody>
# <tr><th>Discipline</th></tr></tbody></table></div></div></body></html>
# <th>Rank</th>
# <tr>
# <td align="left" bgcolor="#ffeaca"><font face="Verdana" size="2">Engineering</font></td>
# <td bgcolor="#ffeaca" class="textright"><font color="#000000" face="Verdana" size="2">81413</font></td>
# </tr>
# <tr class="odd">
# <td align="left"><font face="Verdana" size="2">Medical / Dental</font></td>
# <!--td  class="textright" ><font face="Verdana" size="2" color="#000000" >&nbsp;</font></td-->
# <td class="textright"><font color="#000000" face="Verdana" size="2"> Awaiting NEET Results</font></td>
# </tr>
# <tr><td align="left" bgcolor="#ffeaca"><font face="Verdana" size="2">ISMH</font></td>
# <td bgcolor="#ffeaca" class="textright"><font color="#000000" face="Verdana" size="2"> </font></td>
# </tr>
# <tr class="odd"><td align="left"><font face="Verdana" size="2">NATA(Architecture) </font>
# </td></tr>
# <!--td  class="textright"><font face="Verdana" size="2"  color="#000000">&nbsp;</font></td-->
# <td class="textright"><font color="#000000" face="Verdana" size="2"> Awaiting NATA Results</font></td>
#
# <!--<tr><td bgcolor="#ffeaca" align="left" ><font face="Verdana" size="2">Food Science</font></td>
#   <td bgcolor="#ffeaca"  class="textright"><font face="Verdana" size="2"  color="#000000">&nbsp;</font></td>
#
#   </tr> -->
# <tr><td align="left" bgcolor="#ffeaca"><font face="Verdana" size="2">Agriculture BSc.</font></td>
# <td bgcolor="#ffeaca" class="textright"><font color="#000000" face="Verdana" size="2"> </font></td>
# </tr>
# <tr class="odd">
# <td align="left"><font face="Verdana" size="2">Veterinary Science</font></td>
# <td class="textright"><font color="#000000" face="Verdana" size="2"> </font></td>
# </tr>
# <!-- <tr class="odd">
#
# 	  <td  align="left"><font face="Verdana" size="2">BTech. (Agri. Engg.)</font></td>
# 	  <td  class="textright"><font face="Verdana" size="2"  color="#000000">&nbsp;</font></td>
# 	  </tr> -->
# <!--<tr><td bgcolor="#ffeaca" align="left"><font face="Verdana" size="2">Food Science (Practical)</font></td>
# 	  <td bgcolor="#ffeaca"  class="textright"><font face="Verdana" size="2"  color="#000000">&nbsp;</font></td>
# 	  </tr> -->
# <tr><td align="left" bgcolor="#ffeaca"><font face="Verdana" size="2">Agriculture BSc. (Practical)</font></td>
# <td bgcolor="#ffeaca" class="textright"><font color="#000000" face="Verdana" size="2"> </font></td>
# </tr>
# <tr class="odd"><td align="left"><font face="Verdana" size="2">Veterinary (Practical)</font></td>
# <td class="textright"><font color="#000000" face="Verdana" size="2"> </font></td>
# </tr>
# <!--<tr class="odd"><td  align="left"><font face="Verdana" size="2">BTech (Agri Engg.-Practical)</font></td>
# 	  <td   class="textright"><font face="Verdana" size="2"  color="#000000">&nbsp;</font></td>
# 	  </tr> -->
# <tr><td align="left" bgcolor="#ffeaca"><font face="Verdana" size="2">B-PHARMA</font></td>
# <td bgcolor="#ffeaca" class="textright"><font color="#000000" face="Verdana" size="2"> 57815</font></td>
# </tr>
# <tr class="odd"><td align="left"><font face="Verdana" size="2">D-PHARMA</font></td>
# <td class="textright"><font color="#000000" face="Verdana" size="2"> 57822</font></td>
# </tr>
# <tr><td align="left" bgcolor="#ffeaca"><font face="Verdana" size="2">LATERAL ENTRY B-PHARMA</font></td>
# <td bgcolor="#ffeaca" class="textright"><font color="#000000" face="Verdana" size="2"> </font></td>
# </tr>
#
#
#
# <div class="col-lg-5 col-lg-offset-1 col-sm-12">
# <div class="panel panel-primary ">
# <!-- Default panel contents -->
# <div class="panel-heading">Details</div>
# <table class="table table-bordered table-striped">
# <tbody>
# <tr>
# <th>Subject</th>
# <th>QE Marks</th>
# <th>CET Marks</th>
# <th> </th>
# </tr>
# <tr>
# <td bgcolor="#ffeaca" width="34%"><b><font color="#800000" face="Verdana" size="2"> Physics </font></b></td>
# <td align="center" bgcolor="#ffeaca" width="23%"> 72</td><td align="center" bgcolor="#ffeaca"> 24/60 </td>
# <td align="center" bgcolor="#ffeaca"><a href="detailCET2017.asp?sub=physics&amp;cetno=AA007">Details</a></td>
# </tr>
# <tr>
# <td bgcolor="#ffeaca" width="34%"><b><font color="#800000" face="Verdana" size="2">Chemistry</font></b></td>
# <td align="center" bgcolor="#ffeaca" width="23%"> 61</td>
# <td align="center" bgcolor="#ffeaca"> 19/60</td>
# <td align="center" bgcolor="#ffeaca"><a href="detailCET2017.asp?sub=chemistry&amp;cetno=AA007">Details</a></td>
# </tr>
# <tr>
# <td bgcolor="#ffeaca" width="34%"><b><font color="#800000" face="Verdana" size="2">Maths</font></b></td>
# <td align="center" bgcolor="#ffeaca" width="23%"> 43</td>
# <td align="center" bgcolor="#ffeaca"> 28/60</td>
# <td align="center" bgcolor="#ffeaca"><a href="detailCET2017.asp?sub=maths&amp;cetno=AA007">Details</a></td>
# </tr>
# <tr>
# <td bgcolor="#ffeaca" width="34%"><b><font color="#800000" face="Verdana" size="2"> Biology </font></b></td>
# <td align="center" bgcolor="#ffeaca" width="23%"> 0</td>
# <td align="center" bgcolor="#ffeaca"> /60</td>
# <td align="center" bgcolor="#ffeaca"><a href="detailCET2017.asp?sub=biology&amp;cetno=AA007">Details</a></td>
# </tr>
# <tr>
# <td bgcolor="#ffeaca" width="34%"><b><font color="#800000" face="Verdana" size="2">CET
#        Kannada Marks*</font></b></td>
# <td align="center" bgcolor="#ffeaca" width="23%"> </td>
# <td align="center" bgcolor="#ffeaca"> </td>
# <td bgcolor="#ffeaca"> </td>
# </tr>
# <tr>
# <td bgcolor="#ffeaca" colspan="4" style="font-family: Verdana, Geneva, sans-serif; font-size: 12px;">* Kannada Marks for those Candidates claiming eligibility under clause 'c' and 'd' and written Kannada Exam</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <p>
# <div class="panel panel-primary col-lg-12 col-sm-12">
# <table class="table">
# <tbody>
# <tr><td align="middle" bgcolor="#ffbc79">
# <b><font color="#000" face="Verdana" size="2">
#
#         Reason for not Assigning rank</font></b></td></tr>
# <tr>
# <td bgcolor="#8b4513"><b><font color="#ffffff" face="Verdana" size="2"><ul><li>For ISMH because QE P/C/B mark is Zero </li><br/><li>Not Eligible for ISMH because %PCB &lt; 50% - For GM</li><br/><li>Not Eligible for ISMH because Absent in P/C/B in CET </li><br/><li>Not Eligible for Veterinary science PCBE because %PCBE &lt; 50% - For GM.</li><br/></ul>
# </font></b>
# </td></tr>
# </tbody>
# </table>
# </div>
# </p>
#
# <div class="row col-lg-12 col-md-12 col-sm-12 col-xs-12" style="background-color:#222;color:#ABA9A9;font-size:smaller">
# <div class="col-lg-12" style="background-color:#222;">
# <p>Disclaimer: Neither NIC  nor (KEA, Karnataka)is responsible for any inadvertent error that may have crept in the results being published on NET. The results published on net are for immediate information to the examinees. These cannot be treated as original mark sheets.</p>
# </div>
# <div class="col-lg-4" style="background-color:#222;">
# <p>Best viewed in IE 9.0 and above and Chrome and Mozilla Firefox</p>
# </div>
# <div class="col-lg-4" style="background-color:#222;">
# <p>Data Provided by Karnataka Examinations Authority</p>
# </div>
# <div class="col-lg-4" style="background-color:#222;">
# <p>Designed, Developed &amp; Hosted by National Informatics Centre, Karnataka</p>
# </div>
# </div>

# %%
marks=soup.find_all("td",{"align":"center"})#{"class":"table"})
#print(results)
#print(rows)
for result in results:
    print(result.get_text())
results=soup.find_all("font",{"face":"Verdana"}) 
print([result.get_text().replace('\xa0','') for result in results])
# Out:
#  72
#  24/60
# Details
#  61
#  19/60
# Details
#  43
#  28/60
# Details
#  0
#  /60
# Details
#
#
# ['Engineering', '81413', 'Medical / Dental', 'Awaiting NEET Results', 'ISMH', '', 'NATA(Architecture) ', 'Awaiting NATA Results', 'Agriculture BSc.', '', 'Veterinary Science', '', 'Agriculture BSc. (Practical)', '', 'Veterinary (Practical)', '', 'B-PHARMA', '57815', 'D-PHARMA', '57822', 'LATERAL ENTRY B-PHARMA', '', ' Physics ', 'Chemistry', 'Maths', ' Biology ', 'CET\r\n       Kannada Marks*', ' \r\n     \r\n        Reason for not Assigning rank', 'For ISMH because QE P/C/B mark is Zero Not Eligible for ISMH because %PCB < 50% - For GMNot Eligible for ISMH because Absent in P/C/B in CET Not Eligible for Veterinary science PCBE because %PCBE < 50% - For GM.\n']

# %%
name_rollno=soup.find_all("span",{"style":"font-weight: bold"})#{"class":"table"})
print(name)
# Out:
# [<span style="font-weight: bold">  ANDAPPAGARI KANTHIKIRAN REDDY</span>, <span style="font-weight: bold"> AA007</span>]

# %%
import pandas as pd
df = pd.DataFrame(columns=('Name', 'RollNo', 'Engineering','Medical / Dental','ISMH','NATA(Architecture) ','Agriculture BSc.',
                          'Veterinary Science','Agriculture BSc. (Practical)','Veterinary (Practical)','B-PHARMA','D-PHARMA',
                          'LATERAL ENTRY B-PHARMA'))
df.loc[0]=[*[name_rolln.get_text() for name_rolln in name_rollno],*[results[i].get_text().replace("\xa0","") for i in range(1,22,2)]]

# %%
print(df)
# Out:
#                               Name  RollNo Engineering       Medical / Dental  \
# 0    ANDAPPAGARI KANTHIKIRAN REDDY   AA007       81413  Awaiting NEET Results
#
#   ISMH    NATA(Architecture)  Agriculture BSc. Veterinary Science  \
# 0       Awaiting NATA Results
#
#   Agriculture BSc. (Practical) Veterinary (Practical) B-PHARMA D-PHARMA  \
# 0                                                        57815    57822
#
#   LATERAL ENTRY B-PHARMA
# 0
